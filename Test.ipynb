# %% [markdown]
# ![Screenshot-2017-12-18%20Do%20You%20Want%20Food%20Poisoning%20-%20Technical%20Report%20Morelli.png](attachment:Screenshot-2017-12-18%20Do%20You%20Want%20Food%20Poisoning%20-%20Technical%20Report%20Morelli.png)

# %%
import numpy as np
import random

# %%
x=(["Cat", "Dog", "Snail", "Goldfish"])
print (random.choice(x))
# Out:
# Snail
